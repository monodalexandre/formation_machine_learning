# %%
import numpy as np
import pandas as pd

raw = pd.read_csv('/Users/alexandremonod/Python/OC ML/p2/csv/products.csv', sep='\t')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,35,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
raw.code
# Out:
# 0                  3087
# 1                  4530
# 2                  4559
# 3                 16087
# 4                 16094
#               ...
# 320767    9948282780603
# 320768         99567453
# 320769    9970229501521
# 320770    9980282863788
# 320771     999990026839
# Name: code, Length: 320772, dtype: object

# %%
raw[raw.product_name == "Pepsi"]
# Out:
#                  code                                                url  \
# 415         886100252  http://world-fr.openfoodfacts.org/produit/0000...
# 10306     12000109416  http://world-fr.openfoodfacts.org/produit/0012...
# 111455       01223004  http://world-fr.openfoodfacts.org/produit/0122...
# 127299        6942508  http://world-fr.openfoodfacts.org/produit/0694...
# 140648   748252710918  http://world-fr.openfoodfacts.org/produit/0748...
# 235784  3502110000880  http://world-fr.openfoodfacts.org/produit/3502...
# 235825  3502110005038  http://world-fr.openfoodfacts.org/produit/3502...
# 235868  3502110006318  http://world-fr.openfoodfacts.org/produit/3502...
# 235892  3502110007377  http://world-fr.openfoodfacts.org/produit/3502...
# 235916  3502110008329  http://world-fr.openfoodfacts.org/produit/3502...
# 262435  4060800001740  http://world-fr.openfoodfacts.org/produit/4060...
# 262436  4060800001771  http://world-fr.openfoodfacts.org/produit/4060...
# ...
