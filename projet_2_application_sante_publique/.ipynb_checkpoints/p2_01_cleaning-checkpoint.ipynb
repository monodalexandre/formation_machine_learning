# %% [markdown]
# # SUMMARY
#
# ## [Import libraries and files](#ch0)
#
# # [1 - Feature selection](#ch1)
#
# # [2 - Feature engineering](#ch2)
#
# ## [Export](#ch99)

# %% [markdown]
# <a id="ch0"></a>
# ## Import libraries and files

# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [17], in <cell line: 5>()
#       3 import datetime as dt
#       4 import matplotlib.pyplot as plt
# ----> 5 import seaborn as sns
#       6 import math
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
raw = pd.read_csv("products.csv", sep='\t')
countries = pd.read_csv("countries.csv")
countries = countries[["fr", "en"]]
# Out:
# /var/folders/z3/8962l16x2hbb_4qm7s2df7gc0000gn/T/ipykernel_2852/9275172.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,35,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv("products.csv", sep='\t')

# %% [markdown]
# <a id="ch1"></a>
# # 1 - Feature selection

# %%
# Check data

print(len(list(raw.columns)))
pd.set_option('display.max_columns', 200)
raw.head(2)
# Out:
# 162
#    code                                                url  \
# 0  3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1  4530  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
#
#   generic_name quantity packaging packaging_tags           brands  \
# 0          NaN      1kg       NaN            NaN  Ferme t'y R'nao
# 1          NaN      NaN       NaN            NaN              NaN
#
#        brands_tags categories categories_tags categories_fr origins  \
# 0  ferme-t-y-r-nao        NaN             NaN           NaN     NaN
# ...

# %%
# Columns, sorted by their filling

'''# Drop the many very useless columns

# Drop first technical columns
raw = raw.drop(columns=raw.columns[0:7])

# Drop empty/almost-empty columns
threshold_columns = raw.count().max()/100*10    # Drop columns with 10% values or less
raw = raw.drop(columns=raw.columns[raw.count()<=threshold_columns])

# Drop tags columns
raw = raw[[x for x in raw if not x.endswith("tags")]]

# Drop columns with images
raw = raw[[x for x in raw if not x.startswith("image")]]

# When duplicates, drop columns that have non fr name
# CHECK BEFORE WHICH ONE HAS MOST VALUES
raw = raw.drop(columns=["categories", 
        "labels", "countries", 'additives', "states","main_category", "nutrition-score-uk_100g"])'''
# Out:
# '# Drop the many very useless columns\n\n# Drop first technical columns\nraw = raw.drop(columns=raw.columns[0:7])\n\n# Drop empty/almost-empty columns\nthreshold_columns = raw.count().max()/100*10    # Drop columns with 10% values or less\nraw = raw.drop(columns=raw.columns[raw.count()<=threshold_columns])\n\n# Drop tags columns\nraw = raw[[x for x in raw if not x.endswith("tags")]]\n\n# Drop columns with images\nraw = raw[[x for x in raw if not x.startswith("image")]]\n\n# When duplicates, drop columns that have non fr name\n# CHECK BEFORE WHICH ONE HAS MOST VALUES\nraw = raw.drop(columns=["categories", \n        "labels", "countries", \'additives\', "states","main_category", "nutrition-score-uk_100g"])'

# %%
# Second drop : identify and keep useful columns
# Take Pnns_1 or pnns_2
useful_columns = ["product_name", "main_category_fr", "brands", "nutrition-score-fr_100g", "additives_fr", "manufacturing_places", "labels_fr"]
data = raw[useful_columns]

# Drop when no brand (useless)
data.dropna(subset="brands", inplace=True)
data.reset_index(inplace=True, drop = True)
# Out:
# /var/folders/z3/8962l16x2hbb_4qm7s2df7gc0000gn/T/ipykernel_2852/298596256.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(subset="brands", inplace=True)

# %% [markdown]
# <a id="ch2"></a>
# # 2 - Feature Engineering

# %%
# Imputation missing values

# # With median and where pnns is the same

# %% [markdown]
# <a id="ch2-1"></a>
# ## 2-1 - Clean manufacturing_places names

# %%
# Too many names : get only the country

data.manufacturing_places.unique()
# Out:
# array([nan, 'Brossard Québec', 'United Kingdom', ...,
#        'Warnambool Australia',
#        'Benifaió,Valencia,Comunidad valenciana,España',
#        'Carib Brewery Ltd,Champs Fleurs,Trinidad,W.I.'], dtype=object)

# %%
# Some countries are named in French, others in English
# --> import list of all countries in French and English

list_countries_fr = countries["fr"]
list_countries_uk = countries["en"]
list_countries = list_countries_fr.append(list_countries_uk)
# Out:
# /var/folders/z3/8962l16x2hbb_4qm7s2df7gc0000gn/T/ipykernel_2852/3102416363.py:6: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   list_countries = list_countries_fr.append(list_countries_uk)

# %%
# Essai 1

# ATTENTION 30 min d'exécution !
# Cleaning selected values

# Countries are either named by their English name, either by their French name

"""for i in data["manufacturing_places"].astype(str):
    for j in list_countries :
        if j in i :
            data["manufacturing_places"] = j"""

## Export df
"""data.to_csv("data_country.csv", index=False)
"""

## Open dataset
'''data_countries = pd.read_csv("data_country.csv")
'''
# Essai 2

'''for i in data["manufacturing_places"].astype(str):
    for j in list_countries :
        if j in i :
            data[data["manufacturing_places"]==i] = j'''

# Essai 3

'''for i in data["manufacturing_places"].astype(str):
    for j in list_countries :
        if bool(re.search(j,i))==True:
            data["manufacturing_places"].loc[i] = j'''
# Out:
# 'for i in data["manufacturing_places"].astype(str):\n    for j in list_countries :\n        if bool(re.search(j,i))==True:\n            data["manufacturing_places"].loc[i] = j'

# %% [markdown]
# Essai 1 : Ne marche pas : tous les pays s'appellent "Japan" Essai 2 : Ne produit aucun effet Essai 3 : met plus de 50min à s'exécuter - je l'ai arrêté en cours.

# %% [markdown]
# Try str_concents ; str_extract

# %% [markdown]
# <a id="ch2-2"></a>
# ## 2-2 Cleaning labels

# %%
len(data.labels_fr.unique())
# Out:
# 13536

# %%
# Try to group them

# Split labels
data.labels_fr = data.labels_fr.astype(str) # Object --> str
data["labels_fr_split"] = [row.split() for row in data.labels_fr]

# Show most repeated words

# Make categories with them

# New column with only those categories
# Out:
# /var/folders/z3/8962l16x2hbb_4qm7s2df7gc0000gn/T/ipykernel_2852/2091989670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.labels_fr = data.labels_fr.astype(str) # Object --> str
# /var/folders/z3/8962l16x2hbb_4qm7s2df7gc0000gn/T/ipykernel_2852/2091989670.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["labels_fr_split"] = [row.split() for row in data.labels_fr]

# %% [markdown]
# <a id="ch2-3"></a>
# ## 2-3 Imputation nutrition score

# %%
# Change type
data["nutrition-score-fr_100g"] = data["nutrition-score-fr_100g"].astype(float)
# Out:
# /var/folders/z3/8962l16x2hbb_4qm7s2df7gc0000gn/T/ipykernel_2852/2513484709.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["nutrition-score-fr_100g"] = data["nutrition-score-fr_100g"].astype(float)

# %%
# When missing data > 30% : use KNN regressor

# Take all features with 10g : sugar, fat, ...

# Regression matrice : check most linked features to nutriscore

# Testing model : RMSE

'''# Impute by median, with columns brands and category
for index, col in enumerate(data["nutrition-score-fr_100g"]):
    if math.isnan(i) == True:
        masque = (data["brands"] == data.brands.iloc[index]) & (data["main_category_fr"] == data.main_category_fr.iloc[index])
        i = data[masque]["nutrition-score-fr_100g"].median()

# Nb of rows after imputation
nb_rows_nutrition_after = data["nutrition-score-fr_100g"].count()
'''
# Out:
# '# Impute by median, with columns brands and category\nfor index, col in enumerate(data["nutrition-score-fr_100g"]):\n    if math.isnan(i) == True:\n        masque = (data["brands"] == data.brands.iloc[index]) & (data["main_category_fr"] == data.main_category_fr.iloc[index])\n        i = data[masque]["nutrition-score-fr_100g"].median()\n\n# Nb of rows after imputation\nnb_rows_nutrition_after = data["nutrition-score-fr_100g"].count()\n'

# %% [markdown]
# Pas de changement au niveau du nb de lignes renseignées dans la colonne "nutrition_score" :
# l'algo n'a pas marché ou bien il n'y a pas de lignes où il manque le nutriscore quand on a la marque et la catégorie ?

# %% [markdown]
# <a id="ch99"></a>
# ## Export

# %%
data.to_csv("cleaned.csv", index=False)
