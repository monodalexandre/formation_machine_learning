# %% [markdown]
# # SUMMARY
#
# ## 0 - [Import libraries and files](#ch0)
#
# ## 1 - [Data cleaning](#ch1)

# %% [markdown]
# <a id="ch0"></a>
# ## 0 - Import libraries and files

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %% [markdown]
# import seaborn as sns

# %%
raw = pd.read_csv("products.csv", sep='\t')
# Out:
# /var/folders/z3/8962l16x2hbb_4qm7s2df7gc0000gn/T/ipykernel_1959/4177972519.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,35,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw = pd.read_csv("products.csv", sep='\t')

# %% [markdown]
# <a id="ch1"></a>
# ## 1 - Data cleaning

# %%
# Check data

print(len(list(raw.columns)))
pd.set_option('display.max_columns', 200)
raw.head()
# Out:
# 162
#     code                                                url  \
# 0   3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1   4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2   4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4  16094  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# Too many columns. Need to drop some.

# %%
raw.describe()
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  248939.000000                248939.000000
# mean             NaN       1.936024                     0.019659
# std              NaN       2.502019                     0.140524
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      31.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            248939.000000
# mean                         NaN                                 0.055246
# std                          NaN                                 0.269207
# min                          NaN                                 0.000000
# ...

# %%
# Drop first technical columns
raw = raw.drop(columns=raw.columns[0:7])

# Drop empty/almost-empty columns
threshold_columns = raw.count().max()/100*10    # Drop columns with 10% values or less
raw = raw.drop(columns=raw.columns[raw.count()<=threshold_columns])

# Drop tags columns
raw = raw[[x for x in raw if not x.endswith("tags")]]

# Drop columns with images
raw = raw[[x for x in raw if not x.startswith("image")]]

# When duplicates, drop columns that have non fr name
raw = raw.drop(columns=["categories", 
        "labels", "countries", 'additives', "states","main_category", "nutrition-score-uk_100g"])

# %%
print(len(list(raw.columns)))
list(raw.columns)
# Out:
# 38
# ['product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'brands',
#  'categories_fr',
#  'manufacturing_places',
#  'labels_fr',
#  'purchase_places',
#  'stores',
#  'countries_fr',
#  'ingredients_text',
#  'serving_size',
#  'additives_n',
#  'additives_fr',
#  'ingredients_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'states_fr',
#  'main_category_fr',
#  'energy_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'salt_100g',
#  'sodium_100g',
#  'vitamin-a_100g',
#  'vitamin-c_100g',
#  'calcium_100g',
#  'iron_100g',
#  'nutrition-score-fr_100g']

# %%
raw.head()
# Out:
#                      product_name generic_name quantity packaging  \
# 0              Farine de blé noir          NaN      1kg       NaN
# 1  Banana Chips Sweetened (Whole)          NaN      NaN       NaN
# 2                         Peanuts          NaN      NaN       NaN
# 3          Organic Salted Nut Mix          NaN      NaN       NaN
# 4                 Organic Polenta          NaN      NaN       NaN
#
#             brands categories_fr manufacturing_places labels_fr  \
# 0  Ferme t'y R'nao           NaN                  NaN       NaN
# 1              NaN           NaN                  NaN       NaN
# 2   Torn & Glasser           NaN                  NaN       NaN
# 3        Grizzlies           NaN                  NaN       NaN
# 4   Bob's Red Mill           NaN                  NaN       NaN
#
#   purchase_places stores countries_fr  \
# 0             NaN    NaN       France
# 1             NaN    NaN   États-Unis
# 2             NaN    NaN   États-Unis
# ...

# %% [markdown]
# states_fr : résume les informations disponible et les informations manquantes. Résume aussi les informations importantes, finalement ?

# %%
raw.manufacturing_places.unique()
# Out:
# array([nan, 'Brossard Québec', 'United Kingdom', ...,
#        'Warnambool Australia',
#        'Benifaió,Valencia,Comunidad valenciana,España',
#        'Carib Brewery Ltd,Champs Fleurs,Trinidad,W.I.'], dtype=object)

# %%
# Keep several columns for the app

useful_columns = ["product_name", "nutrition-score-fr_100g", "manufacturing_places", "labels_fr"]
data = raw[useful_columns]

# %%
data
# Out:
#                                              product_name  \
# 0                                      Farine de blé noir
# 1                          Banana Chips Sweetened (Whole)
# 2                                                 Peanuts
# 3                                  Organic Salted Nut Mix
# 4                                         Organic Polenta
# ...                                                   ...
# 320767                                  Tomato & ricotta
# 320768  Mint Melange Tea A Blend Of Peppermint, Lemon ...
# 320769                                            乐吧泡菜味薯片
# 320770                           Tomates aux Vermicelles
# 320771                    Sugar Free Drink Mix, Peach Tea
#
#         nutrition-score-fr_100g manufacturing_places labels_fr
# 0                           NaN                  NaN       NaN
# 1                          14.0                  NaN       NaN
# 2                           0.0                  NaN       NaN
# ...
